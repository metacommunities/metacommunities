# %% [markdown]
# # Analysis of repo topic data coverage
#
# The first objective here is to see whether it is possible to account for most of the repos on github using topics gleaned from names and descriptions

# %%
import redis
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
import re
import itertools
import numpy as np
# import mpld3
# mpld3.enable_notebook()

# %%
red = redis.Redis(db='1')

# %%
#get all keys
keys_all = set(red.keys('*'))
#get the intersection keys
keys_int = set(red.keys('*:*'))
#isolate the topic keys
keys = keys_all.difference(keys_int)
keys = list(keys)

# %%
keys
# Out:
# ['documents', 'spam']

# %%
un =red.sunionstore('repos:union', *keys)

# %%
key_sizes = {k:red.scard(k) for k in keys}
index = key_sizes.keys()
repos_df  = pd.DataFrame(key_sizes.values(), index = index, columns=['repo_count'])
plt = repos_df.repo_count.plot(kind='barh')
plt.set_xlabel('count')
labs = plt.set_yticklabels(index)

# %%
## Possible intersections of interest

intersects = []
src_keys = []
dst_keys = []
intersect_df = pd.DataFrame(columns=['domain1', 'domain2', 'intersection'])
for c in itertools.combinations(keys, 2):
    src_keys.append(c[0])
    dst_keys.append(c[1])
    store_key = c[0]+':'+c[1]
    intersects.append(red.sinterstore(store_key, *c))

# %%
intersect_df = pd.DataFrame({'domain1':src_keys, 'domain2':dst_keys, 'intersection':intersects}, columns=['domain1', 'domain2', 'intersection'])
intersect_df.shape
# Out:
# (325, 3)

# %%
intersect_df.intersection.hist(bins = 100)

# %%
intersect_pivot = intersect_df.pivot('domain1', 'domain2', 'intersection')
intersect_pivot_df = intersect_pivot.fillna(value=0, inplace=False)
intersect_pivot_df
# Out:
# domain2                  book  compilers    css  database  datastat  devices  \
# domain1
# book                        0      22397   6603      5530     41126        0
# compilers                   0          0      0     24363         0        0
# css                         0      10177      0      3619         0        0
# database                    0          0      0         0         0        0
# datastat                    0      44542  25355     13082         0        0
# devices                     0          0      0         0         0        0
# dotfiles                    0          0      0         0         0        0
# editor                      0      52149  27817     15569    213486        0
# game                        0          0      0       410         0        0
# geo                         0          0      0       676         0        0
# git                      3979      13074   2203      1035     11744        0
# icon                        0          0      0       494         0        0
# image                    4568       7981   4022       628     16225        0
# integration               182        155     29        31       453        0
# internetprotocol         9573      15408   8514      2236     33740        0
# machinelearning          1612       2974  80549       669     15729        0
# package                     0          0      0      4105         0        0
# policy                      0        575    310        24         0        0
# science                     0          0      0       447         0        0
# server                      0          0      0         0         0        0
# socialmedia                 0          0      0         0         0     3850
# tests                       0          0      0      2267         0        0
# web_frontend_javascript  3600      10484   3792      1333     12688        0
# webframework             3797       5054   4066      2036     12735        0
# webpages                  880       9381    944       681      2555        0
#
# domain2                  dotfiles  editor   game    geo     git   icon   ide  \
# domain1
# book                         1560   32518   6711   2235       0   1084   265
# compilers                    3304       0   5851   3824       0   4752  8060
# css                           989       0   2229   2181       0   7854   170
# database                     1019       0      0      0       0      0   160
# datastat                    11572       0  10759  10846       0  11903  1279
# devices                         0       0      0      0       0      0     0
# dotfiles                        0       0      0      0       0      0   302
# editor                      86080       0  12139  38719       0  11036  1908
# game                          228       0      0   1608       0    644   139
# geo                          1578       0      0      0       0    509    95
# git                          1983   15470    744   1294       0    797   386
# icon                         6920       0      0      0       0      0   778
# image                         614   65839   2822   2188     493   2641   265
# integration                    12    1364      8     41       0     19    48
# internetprotocol             2675   42475   5083   3667       0   2348   516
# machinelearning               287    6276    290    714       0   5504    84
# package                      5861       0      0      0       0      0   416
# policy                        147       0     76    238       0     72     6
# science                        18       0      0      0       0      0     6
# server                       9961       0      0      0       0      0   537
# socialmedia                     0       0      0      0       0      0     0
# tests                         513       0   1782   3375       0    564   451
# web_frontend_javascript       123   14830    752    726       0   1997   531
# webframework                  262   12037    267   2470     806    781   439
# webpages                      304    7033    308    637  151326    317   118
#
# domain2                  integration  internetprotocol  machinelearning  \
# domain1
# book                               0                 0                0
# compilers                          0                 0                0
# css                                0                 0                0
# database                           0                 0                0
# datastat                           0                 0                0
# devices                            0                 0                0
# dotfiles                           0                 0                0
# editor                             0                 0                0
# game                               0                 0                0
# geo                                0                 0                0
# git                              226              4603              488
# icon                               0                 0                0
# image                             51              4619              949
# integration                        0               161                0
# internetprotocol                   0                 0                0
# machinelearning                   22              2758                0
# package                            0                 0                0
# policy                             0                 0                0
# science                            0                 0                0
# server                             0                 0                0
# socialmedia                        0                 0                0
# tests                              0                 0                0
# web_frontend_javascript            0              4007                0
# webframework                      40              4197             2196
# webpages                         163              2583              370
#
# domain2                  package  policy  science  server
# domain1
# book                        8693    2046      369   25040 ...
# compilers                  21660       0     2480   51331 ...
# css                         6924       0      147    9057 ...
# database                       0       0        0   19702 ...
# datastat                   70851    1786     3280   70133 ...
# devices                        0       0        0       0 ...
# dotfiles                       0       0        0       0 ...
# editor                     34427    1607     2263   56169 ...
# game                        1980       0      102    3803 ...
# geo                         2596       0      153    8511 ...
# git                         1919     359       40    5531 ...
# icon                        6447       0        8    8504 ...
# image                       5872     212      329    6384 ...
# integration                  168       2        4     309 ...
# internetprotocol           12436    1083      259   18652 ...
# machinelearning             1576     136      388    3087 ...
# package                        0       0      186   37018 ...
# policy                       232       0       14    1074 ...
# science                        0       0        0     268 ...
# server                         0       0        0       0 ...
# socialmedia                    0       0        0       0 ...
# tests                       4187       0       51    6745 ...
# web_frontend_javascript     2714      22       21    3242 ...
# webframework                1662      47       87    7089 ...
# webpages                    1156     302        9    2464 ...
#
# [25 rows x 25 columns]

# %%
intersect_norm_df = intersect_pivot_df.apply(np.log10)
df = intersect_norm_df.fillna(value = 0)

# %%
df
# Out:
# domain2                      book  compilers       css  database  datastat  \
# domain1
# book                         -inf   4.350190  3.819741  3.742725  4.614116
# compilers                    -inf       -inf      -inf  4.386731      -inf
# css                          -inf   4.007620      -inf  3.558589      -inf
# database                     -inf       -inf      -inf      -inf      -inf
# datastat                     -inf   4.648770  4.404064  4.116674      -inf
# devices                      -inf       -inf      -inf      -inf      -inf
# dotfiles                     -inf       -inf      -inf      -inf      -inf
# editor                       -inf   4.717246  4.444310  4.192261  5.329369
# game                         -inf       -inf      -inf  2.612784      -inf
# geo                          -inf       -inf      -inf  2.829947      -inf
# git                      3.599774   4.116408  3.343014  3.014940  4.069816
# icon                         -inf       -inf      -inf  2.693727      -inf
# image                    3.659726   3.902057  3.604442  2.797960  4.210185
# integration              2.260071   2.190332  1.462398  1.491362  2.656098
# internetprotocol         3.981048   4.187746  3.930134  3.349472  4.528145
# machinelearning          3.207365   3.473341  4.906060  2.825426  4.196701
# package                      -inf       -inf      -inf  3.613313      -inf
# policy                       -inf   2.759668  2.491362  1.380211      -inf
# science                      -inf       -inf      -inf  2.650308      -inf
# server                       -inf       -inf      -inf      -inf      -inf
# socialmedia                  -inf       -inf      -inf      -inf      -inf
# tests                        -inf       -inf      -inf  3.355452      -inf
# web_frontend_javascript  3.556303   4.020527  3.578868  3.124830  4.103393
# webframework             3.579441   3.703635  3.609167  3.308778  4.104999
# webpages                 2.944483   3.972249  2.974972  2.833147  3.407391
#
# domain2                   devices  dotfiles    editor      game       geo  \
# domain1
# book                         -inf  3.193125  4.512124  3.826787  3.349278
# compilers                    -inf  3.519040      -inf  3.767230  3.582518
# css                          -inf  2.995196      -inf  3.348110  3.338656
# database                     -inf  3.008174      -inf      -inf      -inf
# datastat                     -inf  4.063408      -inf  4.031772  4.035270
# devices                      -inf      -inf      -inf      -inf      -inf
# dotfiles                     -inf      -inf      -inf      -inf      -inf
# editor                       -inf  4.934902      -inf  4.084183  4.587924
# game                         -inf  2.357935      -inf      -inf  3.206286
# geo                          -inf  3.198107      -inf      -inf      -inf
# git                          -inf  3.297323  4.189490  2.871573  3.111934
# icon                         -inf  3.840106      -inf      -inf      -inf
# image                        -inf  2.788168  4.818483  3.450557  3.340047
# integration                  -inf  1.079181  3.134814  0.903090  1.612784
# internetprotocol             -inf  3.427324  4.628133  3.706120  3.564311
# machinelearning              -inf  2.457882  3.797683  2.462398  2.853698
# package                      -inf  3.767972      -inf      -inf      -inf
# policy                       -inf  2.167317      -inf  1.880814  2.376577
# science                      -inf  1.255273      -inf      -inf      -inf
# server                       -inf  3.998303      -inf      -inf      -inf
# socialmedia              3.585461      -inf      -inf      -inf      -inf
# tests                        -inf  2.710117      -inf  3.250908  3.528274
# web_frontend_javascript      -inf  2.089905  4.171141  2.876218  2.860937
# webframework                 -inf  2.418301  4.080518  2.426511  3.392697
# webpages                     -inf  2.482874  3.847141  2.488551  2.804139
#
# domain2                       git      icon       ide  integration  \
# domain1
# book                         -inf  3.035029  2.423246         -inf
# compilers                    -inf  3.676876  3.906335         -inf
# css                          -inf  3.895091  2.230449         -inf
# database                     -inf      -inf  2.204120         -inf
# datastat                     -inf  4.075656  3.106871         -inf
# devices                      -inf      -inf      -inf         -inf
# dotfiles                     -inf      -inf  2.480007         -inf
# editor                       -inf  4.042812  3.280578         -inf
# game                         -inf  2.808886  2.143015         -inf
# geo                          -inf  2.706718  1.977724         -inf
# git                          -inf  2.901458  2.586587     2.354108
# icon                         -inf      -inf  2.890980         -inf
# image                    2.692847  3.421768  2.423246     1.707570
# integration                  -inf  1.278754  1.681241         -inf
# internetprotocol             -inf  3.370698  2.712650         -inf
# machinelearning              -inf  3.740678  1.924279     1.342423
# package                      -inf      -inf  2.619093         -inf
# policy                       -inf  1.857332  0.778151         -inf
# science                      -inf      -inf  0.778151         -inf
# server                       -inf      -inf  2.729974         -inf
# socialmedia                  -inf      -inf      -inf         -inf
# tests                        -inf  2.751279  2.654177         -inf
# web_frontend_javascript      -inf  3.300378  2.725095         -inf
# webframework             2.906335  2.892651  2.642465     1.602060
# webpages                 5.179914  2.501059  2.071882     2.212188
#
# domain2                  internetprotocol  machinelearning   package  \
# domain1
# book                                 -inf             -inf  3.939170
# compilers                            -inf             -inf  4.335658
# css                                  -inf             -inf  3.840357
# database                             -inf             -inf      -inf
# datastat                             -inf             -inf  4.850346
# devices                              -inf             -inf      -inf
# dotfiles                             -inf             -inf      -inf
# editor                               -inf             -inf  4.536899
# game                                 -inf             -inf  3.296665
# geo                                  -inf             -inf  3.414305
# git                              3.663041         2.688420  3.283075
# icon                                 -inf             -inf  3.809358
# image                            3.664548         2.977266  3.768786
# integration                      2.206826             -inf  2.225309
# internetprotocol                     -inf             -inf  4.094681
# machinelearning                  3.440594             -inf  3.197556
# package                              -inf             -inf      -inf
# policy                               -inf             -inf  2.365488
# science                              -inf             -inf      -inf
# server                               -inf             -inf      -inf
# socialmedia                          -inf             -inf      -inf
# tests                                -inf             -inf  3.621903
# web_frontend_javascript          3.602819             -inf  3.433610
# webframework                     3.622939         3.341632  3.220631
# webpages                         3.412124         2.568202  3.062958
#
# domain2                    policy   science    server
# domain1
# book                     3.310906  2.567026  4.398634 ...
# compilers                    -inf  3.394452  4.710380 ...
# css                          -inf  2.167317  3.956984 ...
# database                     -inf      -inf  4.294510 ...
# datastat                 3.251881  3.515874  4.845922 ...
# devices                      -inf      -inf      -inf ...
# dotfiles                     -inf      -inf      -inf ...
# editor                   3.206016  3.354685  4.749497 ...
# game                         -inf  2.008600  3.580126 ...
# geo                          -inf  2.184691  3.929981 ...
# git                      2.555094  1.602060  3.742804 ...
# icon                         -inf  0.903090  3.929623 ...
# image                    2.326336  2.517196  3.805093 ...
# integration              0.301030  0.602060  2.489958 ...
# internetprotocol         3.034628  2.413300  4.270725 ...
# machinelearning          2.133539  2.588832  3.489537 ...
# package                      -inf  2.269513  4.568413 ...
# policy                       -inf  1.146128  3.031004 ...
# science                      -inf      -inf  2.428135 ...
# server                       -inf      -inf      -inf ...
# socialmedia                  -inf      -inf      -inf ...
# tests                        -inf  1.707570  3.828982 ...
# web_frontend_javascript  1.342423  1.322219  3.510813 ...
# webframework             1.672098  1.939519  3.850585 ...
# webpages                 2.480007  0.954243  3.391641 ...
#
# [25 rows x 25 columns]

# %%
f = matplotlib.pyplot.figure()

p = plt.pcolor(intersect_pivot_df)
p.set_figure(f)
f.savefig('test.png')
# p.yticks(np.arange(0.5, len(intersect_pivot.index), 1), intersect_pivot.index)
# p.xticks(np.arange(0.5, len(intersect_pivot.columns), 1), intersect_pivot.columns)
# f.show()

# %% [markdown]
# ## Todo -- a heatmap of the intersections

# %%
intersect_df
# Out:
#          domain1                  domain2  intersection
# 0          image                 webpages           230
# 1          image             webframework          1276
# 2          image                      git           493
# 3          image          machinelearning           949
# 4          image              socialmedia             0
# 5          image              integration            51
# 6          image  web_frontend_javascript          5198
# 7          image         internetprotocol          4619
# 8          image                     book          4568
# 9          image                   editor         65839
# 10         image                 datastat         16225
# 11         image                   policy           212
# 12         image                      css          4022
# 13         image                compilers          7981
# 14         image                    tests          1542
# 15         image                     game          2822
# 16         image                      geo          2188
# 17         image                     icon          2641
# 18         image                  package          5872
# 19         image                  science           329
# 20         image                 database           628
# 21         image                  devices             0
# 22         image                   server          6384
# 23         image                 dotfiles           614
# 24         image                      ide           265
# 25      webpages             webframework           215
# 26      webpages                      git        151326
# 27      webpages          machinelearning           370
# 28      webpages              socialmedia             0
# 29      webpages              integration           163
# 30      webpages  web_frontend_javascript           378
# 31      webpages         internetprotocol          2583
# 32      webpages                     book           880
# 33      webpages                   editor          7033
# 34      webpages                 datastat          2555
# 35      webpages                   policy           302
# 36      webpages                      css           944
# 37      webpages                compilers          9381
# 38      webpages                    tests           671
# 39      webpages                     game           308
# 40      webpages                      geo           637
# 41      webpages                     icon           317
# 42      webpages                  package          1156
# 43      webpages                  science             9
# 44      webpages                 database           681
# 45      webpages                  devices             0
# 46      webpages                   server          2464
# 47      webpages                 dotfiles           304
# 48      webpages                      ide           118
# 49  webframework                      git           806
# 50  webframework          machinelearning          2196
# 51  webframework              socialmedia             0
# 52  webframework              integration            40
# 53  webframework  web_frontend_javascript         11874
# 54  webframework         internetprotocol          4197
# 55  webframework                     book          3797
# 56  webframework                   editor         12037
# 57  webframework                 datastat         12735
# 58  webframework                   policy            47
# 59  webframework                      css          4066
#              ...                      ...           ...
#
# [325 rows x 3 columns]
