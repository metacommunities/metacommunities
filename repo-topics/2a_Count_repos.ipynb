# %% [markdown]
# # Repository census
#
# A basic count of the number of distinct repositories in the timelines is a baseline for this work. It is somewhere around 10 million.

# %%
import redis
import matplotlib.pyplot as plt, mpld3
import seaborn
from bs4 import BeautifulSoup
import pandas as pd
import re
mpld3.enable_notebook()

# %%
red = redis.Redis(db='1')

# %%
repo_table = 'metacommunities:github_proper.repo_list'

query = """SELECT count(distinct(repository_url)) FROM [githubarchive:github.timeline] 
"""

repo_count_df = pd.io.gbq.read_gbq(query)
repo_count_df.ix[0]
# Out:
# ---------------------------------------------------------------------------
# ResponseNotReady                          Traceback (most recent call last)
# <ipython-input-5-36b8a7cf3305> in <module>()
#       4 """
#       5
# ----> 6 repo_count_df = pd.io.gbq.read_gbq(query)
#       7 repo_count_df.ix[0]
#       8 red.set('repo_count_timeline', repo_count_df.ix[0])
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/gbq.pyc in read_gbq(query, project_id, destination_table, index_col, col_order, **kwargs)
#     526     client = _authenticate()
#     527
# --> 528     job = client.Query(**query_args)
#     529
#     530     return _parse_data(client, job, index_col=index_col, col_order=col_order)
#
# /usr/local/lib/python2.7/dist-packages/bigquery_client.pyc in Query(self, query, destination_table, create_disposition, write_disposition, priority, preserve_nulls, allow_large_results, dry_run, use_cache, min_completion_ratio, **kwds)
#    1936     request = {'query': query_config}
#    1937     _ApplyParameters(request, dry_run=dry_run)
# -> 1938     return self.ExecuteJob(request, **kwds)
#    1939
#    1940   def Load(self, destination_table_reference, source,
#
# /usr/local/lib/python2.7/dist-packages/bigquery_client.pyc in ExecuteJob(self, configuration, sync, project_id, upload_file, job_id)
#    1601       job = self.RunJobSynchronously(
#    1602           configuration, project_id=project_id, upload_file=upload_file,
# -> 1603           job_id=job_id)
#    1604     else:
#    1605       job = self.StartJob(
#
# /usr/local/lib/python2.7/dist-packages/bigquery_client.pyc in RunJobSynchronously(self, configuration, project_id, upload_file, job_id)
#    1586                           upload_file=None, job_id=None):
#    1587     result = self.StartJob(configuration, project_id=project_id,
# -> 1588                            upload_file=upload_file, job_id=job_id)
#    1589     if result['status']['state'] != 'DONE':
#    1590       job_reference = BigqueryClient.ConstructObjectReference(result)
#
# /usr/local/lib/python2.7/dist-packages/bigquery_client.pyc in StartJob(self, configuration, project_id, upload_file, job_id)
#    1494     result = self.apiclient.jobs().insert(
#    1495         body=job_request, media_body=media_upload,
# -> 1496         projectId=project_id).execute()
#    1497     return result
#    1498
#
# /usr/local/lib/python2.7/dist-packages/bigquery_client.pyc in execute(self, **kwds)
#     308   def execute(self, **kwds):  # pylint: disable=g-bad-name
#     309     try:
# --> 310       return super(BigqueryHttp, self).execute(**kwds)
#     311     except apiclient.errors.HttpError, e:
#     312       # TODO(user): Remove this when apiclient supports logging
#
# /usr/local/lib/python2.7/dist-packages/oauth2client/util.pyc in positional_wrapper(*args, **kwargs)
#     130         else: # IGNORE
#     131           pass
# --> 132       return wrapped(*args, **kwargs)
#     133     return positional_wrapper
#     134
#
# /usr/local/lib/python2.7/dist-packages/apiclient/http.pyc in execute(self, http, num_retries)
#     714
#     715       resp, content = http.request(str(self.uri), method=str(self.method),
# --> 716                                    body=self.body, headers=self.headers)
#     717       if resp.status < 500:
#     718         break
#
# /usr/local/lib/python2.7/dist-packages/oauth2client/util.pyc in positional_wrapper(*args, **kwargs)
#     130         else: # IGNORE
#     131           pass
# --> 132       return wrapped(*args, **kwargs)
#     133     return positional_wrapper
#     134
#
# /usr/local/lib/python2.7/dist-packages/oauth2client/client.pyc in new_request(uri, method, body, headers, redirections, connection_type)
#     488
#     489       resp, content = request_orig(uri, method, body, clean_headers(headers),
# --> 490                                    redirections, connection_type)
#     491
#     492       if resp.status in REFRESH_STATUS_CODES:
#
# /usr/local/lib/python2.7/dist-packages/httplib2/__init__.pyc in request(self, uri, method, body, headers, redirections, connection_type)
#    1568                     content = ""
#    1569                 else:
# -> 1570                     (response, content) = self._request(conn, authority, uri, request_uri, method, body, headers, redirections, cachekey)
#    1571         except Exception, e:
#    1572             if self.force_exception_to_status_code:
#
# /usr/local/lib/python2.7/dist-packages/httplib2/__init__.pyc in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1315             auth.request(method, request_uri, headers, body)
#    1316
# -> 1317         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1318
#    1319         if auth:
#
# /usr/local/lib/python2.7/dist-packages/httplib2/__init__.pyc in _conn_request(self, conn, request_uri, method, body, headers)
#    1284                     continue
#    1285             try:
# -> 1286                 response = conn.getresponse()
#    1287             except (socket.error, httplib.HTTPException):
#    1288                 if i < RETRIES-1:
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1031         #
#    1032         if self.__state != _CS_REQ_SENT or self.__response:
# -> 1033             raise ResponseNotReady()
#    1034
#    1035         args = (self.sock,)
#
# ResponseNotReady:

# %%
red.set('repo_count_timeline', repo_count_df.ix[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e6ba85ac16ff> in <module>()
# ----> 1 red.set('repo_count_timeline', repo_count_df.ix[0])
#
# NameError: name 'repo_count_df' is not defined

# %%
query_sample = """select repository_owner, repository_name,
if (hash(repository_url) % 100000 == 0, 'True', 'False') as included
from [githubarchive:github.timeline]  limit 100"""
repos_sample = pd.io.gbq.read_gbq(query_sample)
repos_sample.head(30)
# Out:
#       repository_owner             repository_name included
# 0               adam-p               markdown-here    False
# 1         samsalisbury                    shouldly    False
# 2                qerub                    rackjure    False
# 3                 reuk  impulse-response-raytracer    False
# 4            steinarvk                shufflestega    False
# 5               guille                        spot    False
# 6              shelldn                   ajax-auth    False
# 7              dev1991                 wtf_project    False
# 8             snowplow              website-reboot    False
# 9        processing-js               processing-js    False
# 10          githumtime                  githubtime    False
# 11                M66B                    XPrivacy    False
# 12             sunglim                       spark    False
# 13          githumtime                 githubprime    False
# 14             openatv                     enigma2    False
# 15                 rg3                  youtube-dl    False
# 16  ros-infrastructure            rosdoc_tag_index    False
# 17       wildfiremedia                        wfm2    False
# 18              jmhale                  xbmcposttv    False
# 19          hewigovens          PackageUninstaller    False
# 20           crbassett         crbassett.github.io    False
# 21            XhmikosR                      mpc-hc    False
# 22    wordpress-mobile               WordPress-iOS    False
# 23           LinguaLeo                   php-cache    False
# 24           sc00byd00    Sc00byd00-Bukkit-Plugins    False
# 25             gleesin                  mtg-pricer    False
# 26                9chu                     fancy2d    False
# 27            itigoppo                      ponpon    False
# 28               qrush            qrush.github.com    False
# 29          PatchNotes              PatchNotes.org    False
#
# [30 rows x 3 columns]

# %% [markdown]
# We know that there are more on Github, but this is a reasonable number to work with -- 10M.

# %%
query = """SELECT count(distinct(full_name)) FROM [metacommunities:github_proper.repo_list] 
"""

full_repo_count_df = pd.io.gbq.read_gbq(query)
# Out:
# Waiting on bqjob_r23ff6a1347af59bf_00000146000b03e3_2 ... (0s) Current status: DONE

# %%
full_repo_count_df.ix[0]
red.set('repo_count_api', full_repo_count_df.ix[0])
# Out:
# True
