# %% [markdown]
# # Repositories by event histories: top 100
#
# A simple way to gauge the importance of github repositories is just by counting sheer number of events. (There is a 'mistake' in this approach, but potentially an interesting one.)

# %%
import google_bigquery_access as gbq
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
query  = """SELECT repository_name, RepoEvents
FROM
(
    SELECT repository_name, COUNT(repository_name) AS RepoEvents
    FROM [githubarchive:github.timeline]
    GROUP BY repository_name
) MyTable
GROUP BY RepoEvents, repository_name
ORDER BY RepoEvents DESC
limit 100;"""

 
results_df = gbq.query_table(query, max_rows=5000)
# Out:
# executing query:
# SELECT repository_name, RepoEvents
# FROM
# (
#     SELECT repository_name, COUNT(repository_name) AS RepoEvents
#     FROM [githubarchive:github.timeline]
#     GROUP BY repository_name
# ) MyTable
# GROUP BY RepoEvents, repository_name
# ORDER BY RepoEvents DESC
# limit 100;
# has a rows attribute
# 100 of   100 (100, 2)

# %%
results_df
# Out:
#    RepoEvents               repository_name
# 0     1994639       eclipse.platform.common
# 1      690917                      dotfiles
# 2      674907                       try_git
# 3      333753                          test
# 4      317511  eclipse.platform.releng.maps
# 5      293950                     mapserver
# 6      290393                      websites
# 7      265609                    sample_app
# 8      194076                      homebrew
# 9      189707                     bootstrap
# 10     183463                khan-exercises
# 11     163990                liferay-portal
# 12     163374                          gaia
# 13     159774                          core
# 14     155559                         rails
# 15     154344                      euro2012
# 16     129063                     first_app
# 17     122238                          blog
# 18     111577                      demo_app
# 19     106613                   TrinityCore
# 20     100356                       symfony
# 21      95710                          xbmc
# 22      83194                          node
# 23      78822                          rust
# 24      76485                      jboss-as
# 25      75701                      brackets
# 26      75077                  llvm-project
# 27      73293         bcom-homepage-archive
# 28      73142                          Test
# 29      72308                       website
# 30      72288        llvm-project-submodule
# 31      71990                           zf2
# 32      71420                       android
# 33      68652                       pulWifi
# 34      67554               mozilla-central
# 35      66589       android_frameworks_base
# 36      66246                         mstmp
# 37      65435                      gitlabhq
# 38      65296                        moodle
# 39      64958                         scala
# 40      62882                         sympy
# 41      60088               titanium_mobile
# 42      58687                         julia
# 43      57380                          docs
# 44      57321                          salt
# 45      56764                 AtlantissCore
# 46      53690                     mr-issues
# 47      52690                       zamboni
# 48      52371                         linux
# 49      49770                       bitcoin
# 50      49309                     oh-my-zsh
# 51      48943                        django
# 52      48764                    angular.js
# 53      48525                      three.js
# 54      47871                      ember.js
# 55      47606                 jquery-mobile
# 56      47376                        dotvim
# 57      46708                  scikit-learn
# 58      46129                        pdf.js
# 59      45273                         Guido
# 60      45181                        jquery
# 61      45000                     framework
# 62      44859                      backbone
# 63      44794                       ipython
# 64      44430                 HPCC-Platform
# 65      44085                      testrepo
# 66      43212                       ansible
# 67      43100                           git
# 68      42893                        butter
# 69      42892                        meteor
# 70      42875                   Spoon-Knife
# 71      42714  jOOQ-trac-ticket-import-test
# 72      42517                          nova
# 73      41838                    foundation
# 74      41454                         spree
# 75      41389                       scripts
# 76      41324                           vim
# 77      40438                       sandbox
# 78      40418                      diaspora
# 79      40255                   Hello-World
# 80      39807                        pandas
# 81      39739                           yii
# 82      39372                      wet-boew
# 83      39040                       freebsd
# 84      38840                   CodeIgniter
# 85      38821                          akka
# 86      38501                yhadoop-common
# 87      37693                   ci-tracking
# 88      37385               liferay-plugins
# 89      37381          scipy-trac-migration
# 90      37077                 origin-server
# 91      37060             html5-boilerplate
# 92      37003                         Specs
# 93      36938          metasploit-framework
# 94      36902                        phpbb3
# 95      36865                          Elgg
# 96      36807                            d3
# 97      36790                  Font-Awesome
# 98      35733                       maqetta
# 99      35615                  shopp-import

# %% [markdown]
# Some interesting entries in this list. Quite a few of the top repos are just test repos (try-git, test, Test). Some are major projects like the Eclipse software development environment, Mozilla, Moodle, linux, or rails, a Ruby web framework. Others are a bit more surprising, like the [Khan Academy](https://www.khanacademy.org/) Exercises or TrinityCore, a game server, or Euro2012. Or number 33: 'pulWifi shows the default password of some wireless networks'.  Can this repo really be more active than mozilla-central or do we need to distinguish what kinds of events are occurring in it?
#
# ## Repository importance judged by push events
#
# Running a similar query but now just looking at PushEvents. Maybe these give a different idea of repo activity?

# %%
query = """
SELECT repository_name, RepoEvents
FROM
(
    SELECT repository_name, COUNT(repository_name) AS RepoEvents
    FROM [githubarchive:github.timeline]
    WHERE type = 'PushEvent'
    GROUP BY repository_name
) MyTable
GROUP BY RepoEvents, repository_name
ORDER BY RepoEvents DESC
limit 100;

"""
push_results_df = gbq.query_table(query, max_rows=5000)
# Out:
# executing query:
#
# SELECT repository_name, RepoEvents
# FROM
# (
#     SELECT repository_name, COUNT(repository_name) AS RepoEvents
#     FROM [githubarchive:github.timeline]
#     WHERE type = 'PushEvent'
#     GROUP BY repository_name
# ) MyTable
# GROUP BY RepoEvents, repository_name
# ORDER BY RepoEvents DESC
# limit 100;
#
#
# has a rows attribute
# 100 of   100 (100, 2)

# %%
push_results_df
# Out:
#    RepoEvents                 repository_name
# 0      575678                        dotfiles
# 1      290096                        websites
# 2      184146                         try_git
# 3      174069                      sample_app
# 4      154283                        euro2012
# 5       95956                            test
# 6       91575                            blog
# 7       74884                    llvm-project
# 8       73297           bcom-homepage-archive
# 9       72287          llvm-project-submodule
# 10      56766                 mozilla-central
# 11      55117                  liferay-portal
# 12      54899                            core
# 13      53456         android_frameworks_base
# 14      48263                            gaia
# 15      47648                       first_app
# 16      46999                        homebrew
# 17      45166                           Guido
# 18      41786                          moodle
# 19      40917                        demo_app
# 20      40592                          dotvim
# 21      37693                     ci-tracking
# 22      37463                  yhadoop-common
# 23      36524                         freebsd
# 24      36321                         android
# 25      35058                         website
# 26      33261                            xbmc
# 27      33154                            nova
# 28      32909                  jenkins-config
# 29      32687                           rails
# 30      32265                   BrandyMintApp
# 31      31773                         scripts
# 32      28026                 frameworks_base
# 33      27934                        vimfiles
# 34      27001           mozilla-history-tools
# 35      26768                            llvm
# 36      26760                         sandbox
# 37      26743                           clang
# 38      25995                          config
# 39      25807                            docs
# 40      24936                       bootstrap
# 41      24909                          melete
# 42      24858  android_packages_apps_Settings
# 43      24687                            Test
# 44      23948               platform_manifest
# 45      23852                             vim
# 46      23562                            rust
# 47      23357              h0tir0n.github.com
# 48      23067                             git
# 49      22927                           vimrc
# 50      22924                     TrinityCore
# 51      22717                        testrepo
# 52      22402                             zf2
# 53      21899                        .emacs.d
# 54      21770                        jboss-as
# 55      21516                        platform
# 56      21376                            home
# 57      20739                       oh-my-zsh
# 58      20607                         symfony
# 59      20329                       wordpress
# 60      19551                         portage
# 61      19041                            .vim
# 62      18752                     laserTrack2
# 63      18520                       framework
# 64      18250                        irc-logs
# 65      18212                 liferay-plugins
# 66      18058                        Solarmax
# 67      17546                git-achievements
# 68      17398                           linux
# 69      17388                   www.cogent.co
# 70      17237                      infinispan
# 71      17156                         zamboni
# 72      16496                            cobe
# 73      16303                             app
# 74      16138                           feeds
# 75      15721                            salt
# 76      15520             eidogram.github.com
# 77      15457                           Specs
# 78      15380                            ceph
# 79      15294                          puppet
# 80      15028                         configs
# 81      14936                  cmais-frontend
# 82      14924                         emacs.d
# 83      14826                           test1
# 84      14818                              Gv
# 85      14651                   freebsd-ports
# 86      14647                 titanium_mobile
# 87      14617                        Aeon-Nox
# 88      14615                         omrails
# 89      14613                            ruby
# 90      14585                      testrunner
# 91      14577                        frontend
# 92      14576                  phonegap-start
# 93      14336                           scala
# 94      14272                          django
# 95      13887                      vim-config
# 96      13872                          thesis
# 97      13713                       .dotfiles
# 98      13683                           julia
# 99      13664                     nfs-ganesha

# %% [markdown]
# The ordering changes here, although many of the same repo names appear. But that's an important point. There is no single test repository, but quite a few repositories called 'test' or 'thesis' or 'scripts' or 'android' or 'rails'. Obviously repos can have the same name.

# %% [markdown]
# ## Repos without the same name
#
# The problem with querying by repository name is the duplication of names. We can avoid the duplicates by using the repository_url instead of the repository name. The query for that is shown below (still just looking at PushEvents).

# %%
query2  = """SELECT repository_name, repository_url, count(repository_name) as RepoEvents
FROM [githubarchive:github.timeline]
WHERE type = 'PushEvent' OR type = 'ForkEvent'
GROUP BY repository_name, repository_url
ORDER BY RepoEvents DESC
limit 100;"""

repos_dedup_df = gbq.query_table(query2, max_rows=5000)

# %%
repos_dedup_df
# Out:
#    RepoEvents         repository_name  \
# 0      289284                websites
# 1      154224                euro2012
# 2       74960            llvm-project
# 3       73329   bcom-homepage-archive
# 4       72363  llvm-project-submodule
# 5       45053                   Guido
# 6       37738             ci-tracking
# 7       37614          yhadoop-common
# 8       33652         mozilla-central
# 9       32233           BrandyMintApp
# 10      31141                 freebsd
# 11      30654               bootstrap
# 12      27930             Spoon-Knife
# 13      26994   mozilla-history-tools
# 14      24909                  melete
# 15      23330      h0tir0n.github.com
# 16      19924                homebrew
# 17      18745             laserTrack2
# 18      18055                Solarmax
# 19      18009          jenkins-config
# 20      17399           www.cogent.co
# 21      16796                testrepo
# 22      16483                   rails
# 23      16439      hw3_rottenpotatoes
# 24      16340                    cobe
# 25      15577                 portage
# 26      15509     eidogram.github.com
# 27      15479                    llvm
# 28      15378                THE-GAME
# 29      14935          cmais-frontend
# 30      14878         mozilla-central
# 31      14829                    nova
# 32      14824                      Gv
# 33      14800                   feeds
# 34      14742                irc-logs
# 35      14414                    rust
# 36      13858                    gaia
# 37      13805           freebsd-ports
# 38      13416                 gamelib
# 39      12924             HomeworkFox
# 40      12884                   clang
# 41      12743                 hz-base
# 42      12210          jenkins-config
# 43      11727                platform
# 44      11567    mediawiki-extensions
# 45      11536                Aeon-Nox
# 46      11386                  espace
# 47      11226             TrinityCore
# 48      10970                 zamboni
# 49      10910               whitehall
# 50      10507                    ceph
# 51      10469                 blender
# 52      10374                  mantid
# 53      10343              CloudStack
# 54       9870                      v8
# 55       9727      intellij-community
# 56       9700                   Specs
# 57       9694              natcreator
# 58       9659                  django
# 59       9652                    node
# 60       9517                  cloud9
# 61       9396                pupesoft
# 62       9376      hw4_rottenpotatoes
# 63       9347          liferay-portal
# 64       9283                cloudify
# 65       9274             openscholar
# 66       9111                    llvm
# 67       9088             OG-Platform
# 68       9009          liferay-portal
# 69       8940                IRC_Logs
# 70       8786                 php-src
# 71       8664            buildhistory
# 72       8653        planet.sympy.org
# 73       8642                brackets
# 74       8597                    salt
# 75       8524                    ruby
# 76       8408      SOCIETIES-Platform
# 77       8374                   julia
# 78       8366                     mtn
# 79       8349                     zf2
# 80       8244      reach-github-limit
# 81       8159                   spree
# 82       8104                 unisubs
# 83       8087           jquery-mobile
# 84       8078                  cesium
# 85       8077                  backup
# 86       8072             webkit-mips
# 87       7979                  jquery
# 88       7972            freebsd-head
# 89       7892                     app
# 90       7816                 symfony
# 91       7797       html5-boilerplate
# 92       7768              phpmyadmin
# 93       7761       book66.github.com
# 94       7742        thruk-pub-status
# 95       7742            ovirt-engine
# 96       7715                   test1
# 97       7706            clang-mirror
# 98       7658                    nova
# 99       7514                    blog
#
#                                        repository_url
# 0                https://github.com/nyarlabo/websites
# 1             https://github.com/techradical/euro2012
# 2             https://github.com/chapuni/llvm-project
# 3    https://github.com/bcomdlc/bcom-homepage-archive
# 4   https://github.com/chapuni/llvm-project-submodule
# 5                    https://github.com/hughht5/Guido
# 6              https://github.com/crowbar/ci-tracking
# 7      https://github.com/griddynamics/yhadoop-common
# 8          https://github.com/mozilla/mozilla-central
# 9         https://github.com/BrandyMint/BrandyMintApp
# 10                 https://github.com/freebsd/freebsd
# 11               https://github.com/twitter/bootstrap
# 12             https://github.com/octocat/Spoon-Knife
# 13     https://github.com/ehsan/mozilla-history-tools
# 14             https://github.com/sakai-mirror/melete
# 15      https://github.com/H0TIR0N/h0tir0n.github.com
# 16                   https://github.com/mxcl/homebrew
# 17             https://github.com/joebell/laserTrack2
# 18               https://github.com/badwolf9/Solarmax
# 19          https://github.com/wladich/jenkins-config
# 20            https://github.com/cogent/www.cogent.co
# 21               https://github.com/test8590/testrepo
# 22                     https://github.com/rails/rails
# 23     https://github.com/saasbook/hw3_rottenpotatoes
# 24                    https://github.com/niceaji/cobe
# 25                   https://github.com/entoo/portage
# 26    https://github.com/eidogram/eidogram.github.com
# 27                    https://github.com/chapuni/llvm
# 28               https://github.com/YOU-LOST/THE-GAME
# 29             https://github.com/edse/cmais-frontend
# 30             https://github.com/nbp/mozilla-central
# 31                  https://github.com/openstack/nova
# 32                   https://github.com/all4senses/Gv
# 33      https://github.com/runningforworldpeace/feeds
# 34             https://github.com/SeleniumHQ/irc-logs
# 35                    https://github.com/mozilla/rust
# 36                https://github.com/mozilla-b2g/gaia
# 37           https://github.com/freebsd/freebsd-ports
# 38                   https://github.com/STRd6/gamelib
# 39     https://github.com/mindfreakthemon/HomeworkFox
# 40                   https://github.com/chapuni/clang
# 41                https://github.com/Ratmir15/hz-base
# 42       https://github.com/CloudStack/jenkins-config
# 43                   https://github.com/wso2/platform
# 44  https://github.com/wikimedia/mediawiki-extensions
# 45                https://github.com/BigNoid/Aeon-Nox
# 46                https://github.com/realguess/espace
# 47         https://github.com/TrinityCore/TrinityCore
# 48                 https://github.com/mozilla/zamboni
# 49              https://github.com/alphagov/whitehall
# 50                       https://github.com/ceph/ceph
# 51          https://github.com/nicholasbishop/blender
# 52            https://github.com/mantidproject/mantid
# 53           https://github.com/CloudStack/CloudStack
# 54                           https://github.com/v8/v8
# 55    https://github.com/JetBrains/intellij-community
# 56                 https://github.com/CocoaPods/Specs
# 57               https://github.com/ultra2/natcreator
# 58                   https://github.com/django/django
# 59                     https://github.com/joyent/node
# 60                  https://github.com/ajaxorg/cloud9
# 61              https://github.com/devlab-oy/pupesoft
# 62     https://github.com/saasbook/hw4_rottenpotatoes
# 63          https://github.com/liferay/liferay-portal
# 64         https://github.com/CloudifySource/cloudify
# 65         https://github.com/openscholar/openscholar
# 66                https://github.com/llvm-mirror/llvm
# 67           https://github.com/OpenGamma/OG-Platform
# 68  https://github.com/brianchandotcom/liferay-portal
# 69       https://github.com/RedditAndroidDev/IRC_Logs
# 70                     https://github.com/php/php-src
# 71  https://github.com/Angstrom-distribution/build...
# 72          https://github.com/sympy/planet.sympy.org
# 73                  https://github.com/adobe/brackets
# 74                  https://github.com/saltstack/salt
# 75                       https://github.com/ruby/ruby
# 76    https://github.com/societies/SOCIETIES-Platform
# 77                 https://github.com/JuliaLang/julia
# 78                     https://github.com/dodefey/mtn
# 79               https://github.com/zendframework/zf2
# 80       https://github.com/itroot/reach-github-limit
# 81                     https://github.com/spree/spree
# 82                https://github.com/pculture/unisubs
# 83            https://github.com/jquery/jquery-mobile
# 84    https://github.com/AnalyticalGraphicsInc/cesium
# 85                   https://github.com/clcccc/backup
# 86              https://github.com/paul99/webkit-mips
# 87                   https://github.com/jquery/jquery
# 88            https://github.com/freebsd/freebsd-head
# 89                       https://github.com/Wikia/app
# 90                 https://github.com/symfony/symfony
# 91          https://github.com/h5bp/html5-boilerplate
# 92           https://github.com/phpmyadmin/phpmyadmin
# 93        https://github.com/book66/book66.github.com
# 94          https://github.com/xenim/thruk-pub-status
# 95   https://github.com/gerrit-ovirt-org/ovirt-engine
# 96              https://github.com/sharpiceberg/test1
# 97           https://github.com/spurious/clang-mirror
# 98           https://github.com/citrix-openstack/nova
# 99                   https://github.com/scmaccal/blog

# %% [markdown]
# This does clear out all the 'test', 'core' or 'android' sites, and also leaves some surprising results. The top two repos by pushes and forks are 'websites' and 'euro2012.' Both repositories do not currently exist on github. What happened to them? (It could be worth looking at the delete repo events?)
#
# The first proper repo is 'llvm', a highly recognised compiler-virtual machine project that was awarded the 2012 ACM Software System Award.

# %% [markdown]
# ## Repos with the same name
#
# But maybe the copying of repo names would be a useful lead for us in tracking metacommunity dynamics. This is similar to tracking the fork/pull-request dynamics, but via a looser coupling. Commonly used repo names might designate _prototypes_ for repositories more generally. For instance, one of the top repo names in the PushEvents query shown above was 'dotfiles.' An exploration of 'dotfile(s)' repos might tell us something about code editing practices.

# %%
query4  = """SELECT repository_name, repository_url, count(repository_name) as RepoEvents
FROM [githubarchive:github.timeline]
WHERE type = 'PushEvent' AND REGEXP_MATCH(repository_name, 'dotfile(s?)')
GROUP BY repository_name, repository_url
ORDER BY RepoEvents DESC;"""

dotfiles_df = gbq.query_table(query4, 100)
# Out:
# executing query:
# SELECT repository_name, repository_url, count(repository_name) as RepoEvents
# FROM [githubarchive:github.timeline]
# WHERE type = 'PushEvent' AND REGEXP_MATCH(repository_name, 'dotfile(s?)')
# GROUP BY repository_name, repository_url
# ORDER BY RepoEvents DESC     LIMIT 100;
# has a rows attribute
# 100 of   100 (100, 3)

# %%
query5  = """ SELECT count(repository_url) from [githubarchive:github.timeline]
where type = 'CreateEvent' AND REGEXP_MATCH(repository_name, 'dotfiles?')"""

dotfile_repo_count = gbq.query_table(query5)
# Out:
# executing query:
#  SELECT count(repository_url) from [githubarchive:github.timeline]
# where type = 'CreateEvent' AND REGEXP_MATCH(repository_name, 'dotfiles?')    LIMIT 1000000;
# has a rows attribute
# 1 of   1 (1, 1)
#      f0_
# 0  55448

# %%
print dotfile_repo_count.f0_
# Out:
# 0    55448
# Name: f0_

# %% [markdown]
# This suggests that around 55,000 repositories are concerned with 'dotfile(s)' for code editors such as vim, emacs, etc. Many other versions of 'dotfiles' can be found. Repo names that begin with '.' are often configuration files for code editors or command line shells (bash, zsh, etc). A more sophisticated search might just track repositories that concern coding practices. This would perhaps give some lead on how _practices_ of coding move around in the code commons.

# %%
dotfiles_df
# Out:
#    RepoEvents          repository_name  \
# 0        1886   dotfiles-thomasf-emacs
# 1        1155                 dotfiles
# 2        1118                 dotfiles
# 3        1107                 dotfiles
# 4        1020                 dotfiles
# 5         966                 dotfiles
# 6         951                 dotfiles
# 7         950                 dotfiles
# 8         836                 dotfiles
# 9         789                 dotfiles
# 10        787                 dotfiles
# 11        744                 dotfiles
# 12        744           emacs-dotfiles
# 13        706                 dotfiles
# 14        681                 dotfiles
# 15        672                 dotfiles
# 16        667                 dotfiles
# 17        666                 dotfiles
# 18        658  dotfiles-thomasf-xmonad
# 19        649                 dotfiles
# 20        649                 dotfiles
# 21        639                 dotfiles
# 22        631                 dotfiles
# 23        613                 dotfiles
# 24        606                 dotfiles
# 25        603                 dotfiles
# 26        601                 dotfiles
# 27        595                 dotfiles
# 28        584                 dotfiles
# 29        578                 dotfiles
# 30        577                 dotfiles
# 31        544                 dotfiles
# 32        541                 dotfiles
# 33        535                 dotfiles
# 34        531                 dotfiles
# 35        527                 dotfiles
# 36        515                 dotfiles
# 37        512                 dotfiles
# 38        510                 dotfiles
# 39        507                 dotfiles
# 40        506                 dotfiles
# 41        501                 dotfiles
# 42        499                 dotfiles
# 43        498                 dotfiles
# 44        496                 dotfiles
# 45        495                 dotfiles
# 46        494      craigcitro-dotfiles
# 47        493                 dotfiles
# 48        492                 dotfiles
# 49        492                 dotfiles
# 50        481                .dotfiles
# 51        481                 dotfiles
# 52        476                 dotfiles
# 53        470                 dotfiles
# 54        470                 dotfiles
# 55        460                 dotfiles
# 56        454                 dotfiles
# 57        453                 dotfiles
# 58        448                 dotfiles
# 59        447                 dotfiles
# 60        447                 dotfiles
# 61        446                 dotfiles
# 62        443                 dotfiles
# 63        442                 dotfiles
# 64        438                 dotfiles
# 65        437                 dotfiles
# 66        435                 dotfiles
# 67        434                 dotfiles
# 68        433                 dotfiles
# 69        426                 dotfiles
# 70        418                 dotfiles
# 71        416                 dotfiles
# 72        413    dotfiles-thomasf-base
# 73        411                 dotfiles
# 74        411           wunki-dotfiles
# 75        409                 dotfiles
# 76        404                 dotfiles
# 77        404                 dotfiles
# 78        396                 dotfiles
# 79        393                 dotfiles
# 80        387                 dotfiles
# 81        386                 dotfiles
# 82        385                .dotfiles
# 83        385                 dotfiles
# 84        385                .dotfiles
# 85        385                 dotfiles
# 86        384                 dotfiles
# 87        383                 dotfiles
# 88        382                .dotfiles
# 89        381                 dotfiles
# 90        379                 dotfiles
# 91        377                 dotfiles
# 92        377                 dotfiles
# 93        375                 dotfiles
# 94        374                 dotfiles
# 95        373                 dotfiles
# 96        373                 dotfiles
# 97        371                 dotfiles
# 98        370                 dotfiles
# 99        370                 dotfiles
#
#                                        repository_url
# 0   https://github.com/thomasf/dotfiles-thomasf-emacs
# 1             https://github.com/camthompson/dotfiles
# 2             https://github.com/markcornick/dotfiles
# 3                 https://github.com/svnpenn/dotfiles
# 4             https://github.com/baskerville/dotfiles
# 5                https://github.com/benohara/dotfiles
# 6                    https://github.com/daoo/dotfiles
# 7              https://github.com/Happy-Dude/dotfiles
# 8                https://github.com/chastell/dotfiles
# 9               https://github.com/DeeNewcum/dotfiles
# 10              https://github.com/hdgarrood/dotfiles
# 11            https://github.com/craigbarnes/dotfiles
# 12     https://github.com/gorakhargosh/emacs-dotfiles
# 13                   https://github.com/10sr/dotfiles
# 14                  https://github.com/mytoh/dotfiles
# 15                  https://github.com/Mytho/dotfiles
# 16                https://github.com/kusnier/dotfiles
# 17       https://github.com/wayneashleyberry/dotfiles
# 18  https://github.com/thomasf/dotfiles-thomasf-xm...
# 19                   https://github.com/maio/dotfiles
# 20                    https://github.com/jcf/dotfiles
# 21               https://github.com/EvanHahn/dotfiles
# 22               https://github.com/brotatos/dotfiles
# 23               https://github.com/linduxed/dotfiles
# 24                https://github.com/grawity/dotfiles
# 25                   https://github.com/bjin/dotfiles
# 26                 https://github.com/jmatth/dotfiles
# 27                https://github.com/uggedal/dotfiles
# 28                  https://github.com/naoty/dotfiles
# 29               https://github.com/mkomitee/dotfiles
# 30                  https://github.com/vodik/dotfiles
# 31                 https://github.com/naggie/dotfiles
# 32            https://github.com/mindriot101/dotfiles
# 33                 https://github.com/nilved/dotfiles
# 34                   https://github.com/w0ng/dotfiles
# 35                   https://github.com/tejr/dotfiles
# 36          https://github.com/mathiasbynens/dotfiles
# 37            https://github.com/delphinus35/dotfiles
# 38                 https://github.com/jumski/dotfiles
# 39             https://github.com/simongmzlj/dotfiles
# 40                https://github.com/Poapfel/dotfiles
# 41              https://github.com/mogelbrod/dotfiles
# 42                   https://github.com/skwp/dotfiles
# 43                    https://github.com/idk/dotfiles
# 44                 https://github.com/tdowg1/dotfiles
# 45                https://github.com/everzet/dotfiles
# 46  https://github.com/craigcitro/craigcitro-dotfiles
# 47                 https://github.com/b-ryan/dotfiles
# 48              https://github.com/hyperfunk/dotfiles
# 49                https://github.com/mbezjak/dotfiles
# 50               https://github.com/lukexor/.dotfiles
# 51              https://github.com/numbchild/dotfiles
# 52          https://github.com/mistofvongola/dotfiles
# 53          https://github.com/brandoniffert/dotfiles
# 54                 https://github.com/terlar/dotfiles
# 55              https://github.com/bymathias/dotfiles
# 56        https://github.com/davidosomething/dotfiles
# 57               https://github.com/davesque/dotfiles
# 58             https://github.com/farrelle25/dotfiles
# 59               https://github.com/nicknisi/dotfiles
# 60                 https://github.com/jrbing/dotfiles
# 61            https://github.com/tmsanrinsha/dotfiles
# 62                https://github.com/casucci/dotfiles
# 63                https://github.com/umiyosh/dotfiles
# 64                https://github.com/RyanMcG/dotfiles
# 65             https://github.com/metamorfos/dotfiles
# 66          https://github.com/estrategoreal/dotfiles
# 67             https://github.com/johnantoni/dotfiles
# 68                  https://github.com/rhysd/dotfiles
# 69             https://github.com/davidpdrsn/dotfiles
# 70                  https://github.com/sifue/dotfiles
# 71                 https://github.com/hamaco/dotfiles
# 72   https://github.com/thomasf/dotfiles-thomasf-base
# 73               https://github.com/pekepeke/dotfiles
# 74            https://github.com/wunki/wunki-dotfiles
# 75         https://github.com/laurilehmijoki/dotfiles
# 76               https://github.com/partkyle/dotfiles
# 77               https://github.com/sheldonh/dotfiles
# 78            https://github.com/justinforce/dotfiles
# 79                    https://github.com/pyx/dotfiles
# 80              https://github.com/knakayama/dotfiles
# 81              https://github.com/hutchison/dotfiles
# 82              https://github.com/benswift/.dotfiles
# 83               https://github.com/adamyonk/dotfiles
# 84                 https://github.com/supki/.dotfiles
# 85             https://github.com/SeanTAllen/dotfiles
# 86                 https://github.com/gabebw/dotfiles
# 87               https://github.com/soramugi/dotfiles
# 88                   https://github.com/sdt/.dotfiles
# 89               https://github.com/lpomfrey/dotfiles
# 90                https://github.com/cbodden/dotfiles
# 91              https://github.com/johnoshea/dotfiles
# 92                 https://github.com/ptdorf/dotfiles
# 93                https://github.com/sluchin/dotfiles
# 94              https://github.com/tylerball/dotfiles
# 95               https://github.com/dplarson/dotfiles
# 96                 https://github.com/aereal/dotfiles
# 97                 https://github.com/peplin/dotfiles
# 98              https://github.com/mlsimpson/dotfiles
# 99                 https://github.com/yaroot/dotfiles

# %% [markdown]
# Similar 'prototype' repos might also be found with names like 'website(s)' or 'android'.
#
# It might also be worth looking at the 'forkiness' of these generically named repos.
# Are they more commonly forked than more specific repositories?

# %% [markdown]
# # Repositories by forks and pull requests

# %%
query5 = """SELECT payload_pull_request_base_repo_url, repository_name,
count(payload_pull_request_base_repo_url) as PullRequestEvents, 
count(distinct(payload_pull_request_id)) as DistinctPullRequests,
sum(IF(payload_action = 'opened', 1, 0)) AS PullRequestOpenEvents,
sum(IF(payload_pull_request_head_repo_url == payload_pull_request_base_repo_url AND payload_action = 'opened', 1, 0)) AS IntraRepoPullRequestOpenEvents,
sum(IF(payload_pull_request_merged == 'true', 1, 0)) AS MergedPullRequests,
count(distinct(payload_pull_request_merged_by_login)) AS UsersWhoMerge,
sum(IF(payload_pull_request_merged_by_login == payload_pull_request_user_login, 1, 0)) AS PullRequestMergedBySameUser,
FROM [github_explore.timeline]
WHERE type = 'PullRequestEvent' 
GROUP BY payload_pull_request_base_repo_url, repository_name
ORDER BY PullRequestEvents DESC"""

fork_pull_df = gbq.query_table(query5, 400)
# Out:
# executing query:
# SELECT payload_pull_request_base_repo_url, repository_name,
# count(payload_pull_request_base_repo_url) as PullRequestEvents,
# count(distinct(payload_pull_request_id)) as DistinctPullRequests,
# sum(IF(payload_action = 'opened', 1, 0)) AS PullRequestOpenEvents,
# sum(IF(payload_pull_request_head_repo_url == payload_pull_request_base_repo_url AND payload_action = 'opened', 1, 0)) AS IntraRepoPullRequestOpenEvents,
# sum(IF(payload_pull_request_merged == 'true', 1, 0)) AS MergedPullRequests,
# count(distinct(payload_pull_request_merged_by_login)) AS UsersWhoMerge,
# sum(IF(payload_pull_request_merged_by_login == payload_pull_request_user_login, 1, 0)) AS PullRequestMergedBySameUser,
# FROM [github_explore.timeline]
# WHERE type = 'PullRequestEvent'
# GROUP BY payload_pull_request_base_repo_url, repository_name
# ORDER BY PullRequestEvents DESC    LIMIT 400;
# has a rows attribute
# 400 of   400 (400, 9)

# %%
fork_pull_df.repository_name
# Out:
# 0      liferay-portal
# 1            homebrew
# 2                gaia
# 3               rails
# 4                 zf2
# 5     titanium_mobile
# 6            jboss-as
# 7             symfony
# 8               scala
# 9                salt
# 10            crowbar
# 11      HPCC-Platform
# 12            katello
# 13             butter
# 14              Specs
# ...
# 385               ICS5-Map
# 386                B2W2FRA
# 387              mezzanine
# 388         liferay-portal
# 389    MopaBootstrapBundle
# 390              PHProjekt
# 391                   rose
# 392           Aloha-Editor
# 393              ezpublish
# 394                  jruby
# 395                 SMF2.1
# 396                   iris
# 397                pouchdb
# 398            atom-hopper
# 399                  libuv
# Name: repository_name, Length: 400
