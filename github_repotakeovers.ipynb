# %% [markdown]
# # Github re-naming, takeover or merger?
#
# We have a table of 200k repos that are forks and have at least 4 Push events.
#
# This is basically going through the takeover/renaming/merger analysis that Richard did in early Sept 2013.

# %%
import pandas as pd
import matplotlib.pylab as mpl
import MySQLdb

# %%
#text file with MySQL user on 1st line and password on the 2nd needed!
mysql_details = open('mysql_user_login.txt', 'r')
credentials = mysql_details.readlines()
user = credentials[0].strip()
password = credentials[1].strip()

# mysql database name where the table lives -- could put this into mysql_details.txt?
gh_db = 'github_analysis'

db_conn=MySQLdb.connect(db=gh_db, user=user, passwd = password)

#the table that Richard made from BQ
query = 'select * from bq_forks_aug'

# %%
repos_df = pd.io.sql.read_sql(query, db_conn)

# %%
print(repos_df.columns)
print('table shape: '+str(repos_df.shape))
# Out:
# Index([u'repository_url', u'PushEvents', u'Pushers', u'PushesByOwner', u'minWatchers', u'maxWatchers', u'minSize', u'maxSize', u'minForks', u'maxForks', u'created_at', u'last_push', u'forkurl', u'parenturl', u'parent_repo', u'Parent_PushEvents', u'Parent_Pushers', u'Parent_PushesByOwner', u'Parent_minWatchers', u'Parent_maxWatchers', u'Parent_minSize', u'Parent_maxSize', u'Parent_minForks', u'Parent_maxForks', u'Parent_created_at', u'Parent_last_push', u'PR_fork_base', u'PR_fork_head', u'PR_parent_base', u'PR_parent_head', u'PR_fork_base_merges', u'PR_parent_base_merges', u'PR_fork_base_first', u'PR_fork_base_last', u'PR_parent_base_first', u'PR_parent_base_last', u'PR_between_forkbase', u'PR_between_parentbase', u'PR_between_forkbase_merges', u'PR_between_parentbase_merges', u'PR_between_forkbase_selfmerges', u'PR_between_parentbase_selfmerges', u'PR_between_forkbase_first', u'PR_between_forkbase_last', u'PR_between_parentbase_first', u'PR_between_parentbase_last', u'PR_fork_base_distinctrepos', u'PR_parent_base_distinctrepos', u'PR_fork_base_distinctusers', u'PR_parent_base_distinctusers', u'CommonPushers'], dtype=object)
# table shape: (178039, 51)

# %%
repos_df.repository_url.value_counts().head(20)
# Out:
# https://github.com/cj360/android_device_semc_msm7x30-common     9
# https://github.com/dastin1015/android_kernel_htc_msm8660        7
# https://github.com/cj360/platform_manifest                      6
# https://github.com/SymbolixDEV/TrinityCore                      6
# https://github.com/cj360/android_frameworks_base                6
# https://github.com/cj360/android_device_semc_zeusc              5
# https://github.com/g60madman/android                            5
# https://github.com/TheImmortal/Pokemon-Showdown                 5
# https://github.com/cj360/android_system_core                    5
# https://github.com/cj360/android                                5
# https://github.com/biagio7xD/samsung-kernel-msm7x30             5
# https://github.com/crossfire77/android                          5
# https://github.com/abbofro/platform_manifest                    5
# https://github.com/cj360/android_device_semc_zeus               5
# https://github.com/cj360/android_device_semc_zeus-common        5
# https://github.com/AuxXxilium/android_kernel_htc_m7             5
# https://github.com/X-ROM/android_packages_apps_Settings         5
# https://github.com/X-ROM/android_build                          5
# https://github.com/AmeriCanAndroid/android_device_htc_msm8660-common    5
# https://github.com/erikcas/android_frameworks_base              5
# dtype: int64

# %% [markdown]
# Not sure why this table has duplicate repo names. Richard? I can understand the parent_repos being duplicated, but not the fork repos names ...
# Richard: Didn't expect this. There are ForkEvents tying them to more than one parent, possibly where a user created a fork of a repo, deleted it, and then forked another version of that same repo.
# I wouldn't have expected that table of repository_url to have duplicates and I never checked to see if it did. I've had a look and its because some of the fork repos have ForkEvents tying them to more than one parent (ForkEvents are how I tied the forks to their parents, I assumed one event per fork). There are two possibilities: 1) a user creates a fork of a repo, deletes it and subsequently forks another version of the repo (which is actually a distinct repo but gets the same name as the earlier deleted fork because its being created by the same user). 2) I don't know but it may be possible to fork a branch of a repository and fold it into one's own repository as a distinct branch, and the method I used of tying forks to their parent may have picked up on these events as well. In any case, there are 5,230 forks in the bq_forks_aug table which have 'more than one parent'. I will have a look and see if I can find out if the above explanations fit (it should be possible to rule out the 2nd).

# %%
print(repos_df.parent_repo.value_counts().head(30))
# Out:
# https://github.com/mxcl/homebrew                                626
# https://github.com/robbyrussell/oh-my-zsh                       591
# https://github.com/twitter/bootstrap                            572
# https://github.com/rails/rails                                  404
# https://github.com/mathiasbynens/dotfiles                       367
# https://github.com/phonegap/phonegap-start                      354
# https://github.com/CocoaPods/Specs                              349
# https://github.com/holman/dotfiles                              288
# https://github.com/django/django                                276
# https://github.com/imathis/octopress                            250
# https://github.com/CyanogenMod/android_frameworks_base          235
# https://github.com/github/game-off-2012                         233
# https://github.com/wakaleo/game-of-life                         231
# https://github.com/CyanogenMod/android                          230
# https://github.com/symfony/symfony                              225
# https://github.com/TrinityCore/TrinityCore                      213
# https://github.com/zendframework/zf2                            207
# https://github.com/gitlabhq/gitlabhq                            193
# https://github.com/saasbook/hw3_rottenpotatoes                  178
# https://github.com/saasbook/hw4_rottenpotatoes                  174
# https://github.com/xbmc/xbmc                                    173
# https://github.com/ansible/ansible                              171
# https://github.com/laravel/laravel                              155
# https://github.com/EllisLab/CodeIgniter                         154
# https://github.com/cocos2d/cocos2d-x                            153
# https://github.com/saltstack/salt                               153
# https://github.com/mozilla-b2g/gaia                             152
# https://github.com/rioleo/CS147                                 148
# https://github.com/saasbook/hw2_rottenpotatoes                  143
# https://github.com/CyanogenMod/android_packages_apps_Settings    141
# dtype: int64

# %% [markdown]
# ## Overview of the count fields in the table
#
# All plots below just to have a quick look at the kinds of numbers in the table

# %%
plt = repos_df.iloc[:,[2,3,4,5,6,7,8,9, 15,16,17,18,19,20, 21, 22, 23, 26, 27, 28, 29, 30, 31]].hist(bins=100, figsize=(18,14))

# %% [markdown]
# ## Where the fork is more than the parent
#
# Various criteria to look at here:
#
# 1. Fork has the same or more pushes than parent
# 2. Fork has the same or more pushers than parent
# 2. Fork has the same or more watchers than parent
# 3. Fork forks the same or more than parent
# 4. Fork receives the same or more pull requests than parent
#
# Here I'm not taking into account the commonpushers. So this filtering will allow 'renaming' takeovers through. That's ok.

# %%
#more pushes than parent
more_pushes = repos_df[repos_df.PushEvents >= repos_df.Parent_PushEvents]
print('%d where fork has more pushes than the parent'% more_pushes.shape[0])
#more pushers than parent
more_pushers = repos_df[repos_df.Pushers >= repos_df.Parent_Pushers]
print('%d where fork has more pushers than the parent'% more_pushers.shape[0])
#more watchers than parent
more_watchers = repos_df[repos_df.maxWatchers >= repos_df.Parent_maxWatchers]
print('%d where fork has more watchers than the parent'% (more_watchers.shape[0]))

#more forks than parent
more_forks = repos_df[repos_df.maxForks >= repos_df.Parent_maxForks]
print('%d where fork has more forks than the parent'% (more_forks.shape[0]))
more_pullrequest_heads = repos_df[repos_df['PR_fork_base_distinctrepos']> repos_df['PR_parent_base_distinctrepos']]
print('%d where fork has received pull requests from a greater number of distinct head repos than the parent'% (more_pullrequest_heads.shape[0]))

more_pullrequest = repos_df[repos_df['PR_fork_base']> repos_df['PR_parent_base']]
print('%d where fork has received more pull request events than the parent'% (more_pullrequest_heads.shape[0]))
# Out:
# 32511 where fork has more pushes than the parent
# 93102 where fork has more pushers than the parent
# 19718 where fork has more watchers than the parent
# 6581 where fork has more forks than the parent
# 2785 where fork has received pull requests from a greater number of distinct head repos than the parent
# 2785 where fork has received more pull request events than the parent

# %%
## to look at intersection of these
push_set = set(more_pushes.index)
forks_greater_than_parents =push_set.intersection(more_pushers.index, more_watchers.index, more_forks.index, more_pullrequest.index)
forks_greater_than_parents_union =push_set.union(more_pushers.index, more_watchers.index, more_forks.index, more_pullrequest.index)
print('%d forks are greater than their parents on every front'%len(forks_greater_than_parents))
print('%d forks are greater than their parents on at least one front'%len(forks_greater_than_parents_union))
# Out:
# 646 forks are greater than their parents on every front
# 102590 forks are greater than their parents on at least one front

# %%
repos_df.ix[forks_greater_than_parents, ['repository_url','parent_repo', 'PushEvents', 'Pushers', 'CommonPushers']].sort('PushEvents', ascending=False).head(20)
# Out:
#                                            repository_url  \
# 9204                      https://github.com/makerbot/s3g
# 62186                 https://github.com/McGill-CSB/PHYLO
# 138885                     https://github.com/radar/spree
# 76103             https://github.com/gsisko/wpi-suite-tng
# 118729     https://github.com/bhanvadia/tegra-linux-3.0.y
# 1496       https://github.com/sublimescala/sublime-ensime
# 58023          https://github.com/Self-Evident/OneFileCMS
# 161499            https://github.com/ayan4m1/DayZ-Private
# 4051             https://github.com/saqirmdev/TrinityCore
# 136060           https://github.com/ruby-china/ruby-china
# 61914                   https://github.com/mpv-player/mpv
# 157674                https://github.com/pophealth/bonnie
# 86266              https://github.com/wg-perception/libmv
# 117397          https://github.com/XYAOSP/frameworks_base
# 58676              https://github.com/overtone/emacs-live
# 91592                    https://github.com/galaxas0/twui
# 37054   https://github.com/PyroMod/android_kernel_htc_...
# 80465          https://github.com/InMobi/messaging-client
# 69209                 https://github.com/mozilla/towtruck
# 111468             https://github.com/RageModDevs/RageMod
#
#                                               parent_repo  PushEvents  \
# 9204                     https://github.com/cibomahto/s3g        1805
# 62186                 https://github.com/alfred-kam/PHYLO        1364
# 138885                https://github.com/iloveitaly/spree        1184
# 76103         https://github.com/fracture91/wpi-suite-tng        1081
# 118729       https://github.com/vadonka/tegra-linux-3.0.y         892
# 1496       https://github.com/michaelpnash/sublime-ensime         731
# 58023           https://github.com/rocktronica/OneFileCMS         692
# 161499          https://github.com/GuruAbdul/DayZ-Private         633
# 4051               https://github.com/Chevron/TrinityCore         622
# 136060             https://github.com/huacnlee/ruby-china         599
# 61914                          https://github.com/wm4/mpv         599
# 157674            https://github.com/projectbonnie/bonnie         596
# 86266                   https://github.com/Nazg-Gul/libmv         586
# 117397  https://github.com/FruitsAndVeggies/frameworks...         583
# 58676              https://github.com/samaaron/emacs-live         574
# 91592                    https://github.com/bitswift/twui         574
# 37054   https://github.com/blahbl4hblah/android_kernel...         568
# 80465        https://github.com/sharadag/messaging-client         541
# 69209                https://github.com/simonwex/towtruck         528
# 111468          https://github.com/PandazNWafflez/RageMod         507
#
#         Pushers  CommonPushers
# 9204         13              1
# 62186         8              1
# 138885        1              0
# 76103        13              0
# 118729        1              0
# 1496          2              0
# 58023         1              0
# 161499        1              0
# 4051          7              0
# 136060        3              3
# 61914         5              1
# 157674        7              1
# 86266         3              0
# 117397        5              0
# 58676         1              1
# 91592         1              0
# 37054         1              1
# 80465         4              1
# 69209         3              1
# 111468        2              1

# %% [markdown]
# This table of 140 repositories should be the most comprehensive takeovers/renamings/mergers on the Github timeline. I guess it doesn't give us too many to analyse.
#
# Richard: how did you get 5662 here?  I either get 34k or 140 (for the full intersection on all fronts).
#
# Richard's response: I get the same figures for the first 2 rows. Where fork has more watchers than parent you are looking at the largest observed figure for parent and fork - I was looking at the growth of this figure over the observation period (difference between min and maxWatchers for fork/parent). Same thing applies for number of forks. Your row about pull requests is actually comparing the number of distinct head repos which made pull requests on the fork/parent, whereas I was looking at number of distinct pull requests.
